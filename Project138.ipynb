# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinithiBala2021/IMPORTING-DATA-FROM-KAGGLE/blob/main/Project138.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7aea4d77-dcb7-45df-b52c-a17b5018f5ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7aea4d77-dcb7-45df-b52c-a17b5018f5ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d gspmoreira/articles-sharing-reading-from-cit-deskdrop
# Out:
# ...
#  61% 5.00M/8.20M [00:00<00:00, 50.2MB/s]
# 100% 8.20M/8.20M [00:00<00:00, 75.7MB/s]

# %%
# !ls
# Out:
# articles-sharing-reading-from-cit-deskdrop.zip	kaggle.json  sample_data

# %%
# !unzip articles-sharing-reading-from-cit-deskdrop.zip
# Out:
# Archive:  articles-sharing-reading-from-cit-deskdrop.zip
#   inflating: shared_articles.csv
#   inflating: users_interactions.csv

# %%
# !ls
# Out:
# articles-sharing-reading-from-cit-deskdrop.zip	shared_articles.csv
# kaggle.json					users_interactions.csv
# sample_data

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('shared_articles.csv')
df2 = pd.read_csv('users_interactions.csv')

# %%
df1.head()
# Out:
#     timestamp        eventType            contentId       authorPersonId  \
# 0  1459192779  CONTENT REMOVED -6451309518266745024  4340306774493623681
# 1  1459193988   CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146   CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474   CONTENT SHARED -6151852268067518688  3891637997717104548
# 4  1459194497   CONTENT SHARED  2448026894306402386  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 0  8940341205206233829             NaN          NaN           NaN        HTML
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
# 3 -1457532940883382585             NaN          NaN           NaN        HTML
# 4  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# ...

# %%
df2.head()
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
# 3  1465413895    FOLLOW   310515487419366995   344280948527967603
# 4  1465412290      VIEW -7820640624231356730  -445337111692715325
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2  2631864456530402479                                                NaN
# 3 -3167637573980064150                                                NaN
# 4  5611481178424124714                                                NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN
# ...

# %%
df1.columns = ['timestamp','event_Type','contentId','authorPersonId','authorSessionId','authorUserAgent','authorRegion','authorCountry','contentType','url','title','text','lang']
df2 = df2.merge(df1,on='timestamp')

# %%
df2.head()
# Out:
#     timestamp eventType          contentId_x             personId  \
# 0  1461689512      VIEW  6989198691754522425  7890134385692540512
# 1  1463600500      VIEW -8669770849634489893   436785895835580263
# 2  1465424159      VIEW -2948321821574578861  7527226129639571966
# 3  1460632316      LIKE -7681408188643141872  7948079555216525045
# 4  1461608361      VIEW -5636731245639685654  4942487288765370891
#
#              sessionId                                          userAgent  \
# 0 -2241007388742885017  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 1  6453978556866260263  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 2  3989456265529686673  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 3  8576548566370225994                                                NaN
# 4  7507187980365281214  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#   userRegion userCountry      event_Type          contentId_y  \
# ...
